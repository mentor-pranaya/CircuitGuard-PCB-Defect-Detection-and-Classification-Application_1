# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt

# === YOUR FOLDER PATHS ===
ROOT_DATA_DIR = r"C:\Users\LENOVO\OneDrive\Desktop\Project"
TEMPLATE_DIR = os.path.join(ROOT_DATA_DIR, "PCB_USED")
ALL_IMAGES_DIR = os.path.join(ROOT_DATA_DIR, "images")
OUTPUT_MASKS_DIR = os.path.join(ROOT_DATA_DIR, "PROCESSED_DEFECT_MASKS")
os.makedirs(OUTPUT_MASKS_DIR, exist_ok=True)

# Template indices (as per dataset)
TEMPLATE_INDICES = ['01', '04', '05', '06', '07', '08', '09', '10', '11', '12']
DEFECT_TYPES = ['Missing_hole', 'Mouse_bite', 'Open_circuit', 'Short', 'Spur', 'Spurious_copper']

# %%
def process_image_pair(template_idx, defect_type, test_img_name):
    """Loads, aligns, subtracts, and thresholds a single PCB pair."""

    # Paths
    template_path = os.path.join(TEMPLATE_DIR, f"{template_idx}.JPG")
    test_img_path = os.path.join(ALL_IMAGES_DIR, defect_type, test_img_name)

    # Read in grayscale
    template = cv2.imread(template_path, 0)
    test_img = cv2.imread(test_img_path, 0)

    if template is None or test_img is None:
        print(f"Skipping {test_img_name} — missing image.")
        return None

    # ORB feature matching for alignment
    orb = cv2.ORB_create(nfeatures=5000)
    kp1, des1 = orb.detectAndCompute(template, None)
    kp2, des2 = orb.detectAndCompute(test_img, None)

    bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
    matches = sorted(bf.match(des1, des2), key=lambda x: x.distance)[:50]

    points1 = np.float32([kp1[m.queryIdx].pt for m in matches]).reshape(-1, 1, 2)
    points2 = np.float32([kp2[m.trainIdx].pt for m in matches]).reshape(-1, 1, 2)

    H, _ = cv2.findHomography(points2, points1, cv2.RANSAC, 5.0)
    aligned_test = cv2.warpPerspective(test_img, H, (template.shape[1], template.shape[0]))

    # Subtract and threshold
    diff = cv2.absdiff(template, aligned_test)
    _, mask_raw = cv2.threshold(diff, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

    # Morphological filtering
    kernel = np.ones((3, 3), np.uint8)
    mask = cv2.dilate(cv2.erode(mask_raw, kernel, 1), kernel, 1)

    return template, aligned_test, mask

# %%
# --- MAIN LOOP ---
for defect_type in DEFECT_TYPES:
    print(f"\nProcessing defect type: {defect_type}")
    current_dir = os.path.join(ALL_IMAGES_DIR, defect_type)
    save_dir = os.path.join(OUTPUT_MASKS_DIR, defect_type)
    os.makedirs(save_dir, exist_ok=True)

    for filename in os.listdir(current_dir):
        if not (filename.endswith(".JPG") or filename.endswith(".jpg")):
            continue

        template_idx = filename.split('_')[0]
        if template_idx not in TEMPLATE_INDICES:
            continue

        result = process_image_pair(template_idx, defect_type, filename)
        if result:
            _, _, mask = result
            mask_name = f"MASK_{filename.replace('.JPG', '.png').replace('.jpg', '.png')}"
            cv2.imwrite(os.path.join(save_dir, mask_name), mask)
            print(f"Saved: {mask_name}")

print("\n✅ All defect masks have been generated successfully!")
# Out:
# Processing defect type: Missing_hole
# Saved: MASK_01_missing_hole_01.png
# Saved: MASK_01_missing_hole_02.png
# Saved: MASK_01_missing_hole_03.png
# Saved: MASK_01_missing_hole_04.png
# Saved: MASK_01_missing_hole_05.png
# Saved: MASK_01_missing_hole_06.png
# Saved: MASK_01_missing_hole_07.png
# Saved: MASK_01_missing_hole_08.png
# Saved: MASK_01_missing_hole_09.png
# Saved: MASK_01_missing_hole_10.png
# Saved: MASK_01_missing_hole_11.png
# Saved: MASK_01_missing_hole_12.png
# Saved: MASK_01_missing_hole_13.png
# Saved: MASK_01_missing_hole_14.png
# Saved: MASK_01_missing_hole_15.png
# Saved: MASK_01_missing_hole_16.png
# Saved: MASK_01_missing_hole_17.png
# Saved: MASK_01_missing_hole_18.png
# Saved: MASK_01_missing_hole_19.png
# Saved: MASK_01_missing_hole_20.png
# Saved: MASK_04_missing_hole_01.png
# Saved: MASK_04_missing_hole_02.png
# Saved: MASK_04_missing_hole_03.png
# Saved: MASK_04_missing_hole_04.png
# Saved: MASK_04_missing_hole_05.png
# Saved: MASK_04_missing_hole_06.png
# Saved: MASK_04_missing_hole_07.png
# Saved: MASK_04_missing_hole_08.png
# Saved: MASK_04_missing_hole_09.png
# Saved: MASK_04_missing_hole_10.png
# Saved: MASK_04_missing_hole_11.png
# Saved: MASK_04_missing_hole_12.png
# Saved: MASK_04_missing_hole_13.png
# Saved: MASK_04_missing_hole_14.png
# Saved: MASK_04_missing_hole_15.png
# Saved: MASK_04_missing_hole_16.png
# Saved: MASK_04_missing_hole_17.png
# Saved: MASK_04_missing_hole_18.png
# Saved: MASK_04_missing_hole_19.png
# Saved: MASK_04_missing_hole_20.png
# Saved: MASK_05_missing_hole_01.png
# Saved: MASK_05_missing_hole_02.png
# Saved: MASK_05_missing_hole_03.png
# Saved: MASK_05_missing_hole_04.png
# Saved: MASK_05_missing_hole_05.png
# Saved: MASK_05_missing_hole_06.png
# Saved: MASK_05_missing_hole_07.png
# Saved: MASK_05_missing_hole_08.png
# Saved: MASK_05_missing_hole_09.png
# Saved: MASK_05_missing_hole_10.png
# Saved: MASK_06_missing_hole_01.png
# Saved: MASK_06_missing_hole_02.png
# Saved: MASK_06_missing_hole_03.png
# Saved: MASK_06_missing_hole_04.png
# Saved: MASK_06_missing_hole_05.png
# Saved: MASK_06_missing_hole_06.png
# Saved: MASK_06_missing_hole_07.png
# Saved: MASK_06_missing_hole_08.png
# Saved: MASK_06_missing_hole_09.png
# Saved: MASK_06_missing_hole_10.png
# Saved: MASK_07_missing_hole_01.png
# Saved: MASK_07_missing_hole_02.png
# Saved: MASK_07_missing_hole_03.png
# Saved: MASK_07_missing_hole_04.png
# Saved: MASK_07_missing_hole_05.png
# Saved: MASK_07_missing_hole_06.png
# Saved: MASK_07_missing_hole_07.png
# Saved: MASK_07_missing_hole_08.png
# Saved: MASK_07_missing_hole_09.png
# Saved: MASK_07_missing_hole_10.png
# Saved: MASK_08_missing_hole_01.png
# Saved: MASK_08_missing_hole_02.png
# Saved: MASK_08_missing_hole_03.png
# Saved: MASK_08_missing_hole_04.png
# Saved: MASK_08_missing_hole_05.png
# Saved: MASK_08_missing_hole_06.png
# Saved: MASK_08_missing_hole_07.png
# Saved: MASK_08_missing_hole_08.png
# Saved: MASK_08_missing_hole_09.png
# Saved: MASK_08_missing_hole_10.png
# Saved: MASK_09_missing_hole_01.png
# Saved: MASK_09_missing_hole_02.png
# Saved: MASK_09_missing_hole_03.png
# Saved: MASK_09_missing_hole_04.png
# Saved: MASK_09_missing_hole_05.png
# Saved: MASK_09_missing_hole_06.png
# Saved: MASK_09_missing_hole_07.png
# Saved: MASK_09_missing_hole_08.png
# Saved: MASK_09_missing_hole_09.png
# Saved: MASK_09_missing_hole_10.png
# Saved: MASK_10_missing_hole_01.png
# Saved: MASK_10_missing_hole_02.png
# Saved: MASK_10_missing_hole_03.png
# Saved: MASK_10_missing_hole_04.png
# Saved: MASK_10_missing_hole_05.png
# Saved: MASK_11_missing_hole_01.png
# Saved: MASK_11_missing_hole_02.png
# Saved: MASK_11_missing_hole_03.png
# Saved: MASK_11_missing_hole_04.png
# Saved: MASK_11_missing_hole_05.png
# Saved: MASK_11_missing_hole_06.png
# Saved: MASK_11_missing_hole_07.png
# Saved: MASK_11_missing_hole_08.png
# Saved: MASK_11_missing_hole_09.png
# Saved: MASK_11_missing_hole_10.png
# Saved: MASK_12_missing_hole_01.png
# Saved: MASK_12_missing_hole_02.png
# Saved: MASK_12_missing_hole_03.png
# Saved: MASK_12_missing_hole_04.png
# Saved: MASK_12_missing_hole_05.png
# Saved: MASK_12_missing_hole_06.png
# Saved: MASK_12_missing_hole_07.png
# Saved: MASK_12_missing_hole_08.png
# Saved: MASK_12_missing_hole_09.png
# Saved: MASK_12_missing_hole_10.png
#
# Processing defect type: Mouse_bite
# Saved: MASK_01_mouse_bite_01.png
# Saved: MASK_01_mouse_bite_02.png
# Saved: MASK_01_mouse_bite_03.png
# Saved: MASK_01_mouse_bite_04.png
# Saved: MASK_01_mouse_bite_05.png
# Saved: MASK_01_mouse_bite_06.png
# Saved: MASK_01_mouse_bite_07.png
# Saved: MASK_01_mouse_bite_08.png
# Saved: MASK_01_mouse_bite_09.png
# Saved: MASK_01_mouse_bite_10.png
# Saved: MASK_01_mouse_bite_11.png
# Saved: MASK_01_mouse_bite_12.png
# Saved: MASK_01_mouse_bite_13.png
# Saved: MASK_01_mouse_bite_14.png
# Saved: MASK_01_mouse_bite_15.png
# Saved: MASK_01_mouse_bite_16.png
# Saved: MASK_01_mouse_bite_17.png
# Saved: MASK_01_mouse_bite_18.png
# Saved: MASK_01_mouse_bite_19.png
# Saved: MASK_01_mouse_bite_20.png
# Saved: MASK_04_mouse_bite_01.png
# Saved: MASK_04_mouse_bite_02.png
# Saved: MASK_04_mouse_bite_03.png
# Saved: MASK_04_mouse_bite_04.png
# Saved: MASK_04_mouse_bite_05.png
# Saved: MASK_04_mouse_bite_06.png
# Saved: MASK_04_mouse_bite_07.png
# Saved: MASK_04_mouse_bite_08.png
# Saved: MASK_04_mouse_bite_09.png
# Saved: MASK_04_mouse_bite_10.png
# Saved: MASK_04_mouse_bite_11.png
# Saved: MASK_04_mouse_bite_12.png
# Saved: MASK_04_mouse_bite_13.png
# Saved: MASK_04_mouse_bite_14.png
# Saved: MASK_04_mouse_bite_15.png
# Saved: MASK_04_mouse_bite_16.png
# Saved: MASK_04_mouse_bite_17.png
# Saved: MASK_04_mouse_bite_18.png
# Saved: MASK_04_mouse_bite_19.png
# Saved: MASK_04_mouse_bite_20.png
# Saved: MASK_05_mouse_bite_01.png
# Saved: MASK_05_mouse_bite_02.png
# Saved: MASK_05_mouse_bite_03.png
# Saved: MASK_05_mouse_bite_04.png
# Saved: MASK_05_mouse_bite_05.png
# Saved: MASK_05_mouse_bite_06.png
# Saved: MASK_05_mouse_bite_07.png
# Saved: MASK_05_mouse_bite_08.png
# Saved: MASK_05_mouse_bite_09.png
# Saved: MASK_05_mouse_bite_10.png
# Saved: MASK_06_mouse_bite_01.png
# Saved: MASK_06_mouse_bite_02.png
# Saved: MASK_06_mouse_bite_03.png
# Saved: MASK_06_mouse_bite_04.png
# Saved: MASK_06_mouse_bite_05.png
# Saved: MASK_06_mouse_bite_06.png
# Saved: MASK_06_mouse_bite_07.png
# Saved: MASK_06_mouse_bite_08.png
# Saved: MASK_06_mouse_bite_09.png
# Saved: MASK_06_mouse_bite_10.png
# Saved: MASK_07_mouse_bite_01.png
# Saved: MASK_07_mouse_bite_02.png
# Saved: MASK_07_mouse_bite_03.png
# Saved: MASK_07_mouse_bite_04.png
# Saved: MASK_07_mouse_bite_05.png
# Saved: MASK_07_mouse_bite_06.png
# Saved: MASK_07_mouse_bite_07.png
# Saved: MASK_07_mouse_bite_08.png
# Saved: MASK_07_mouse_bite_09.png
# Saved: MASK_07_mouse_bite_10.png
# Saved: MASK_08_mouse_bite_01.png
# Saved: MASK_08_mouse_bite_02.png
# Saved: MASK_08_mouse_bite_03.png
# Saved: MASK_08_mouse_bite_04.png
# Saved: MASK_08_mouse_bite_05.png
# Saved: MASK_08_mouse_bite_06.png
# Saved: MASK_08_mouse_bite_07.png
# Saved: MASK_08_mouse_bite_08.png
# Saved: MASK_08_mouse_bite_09.png
# Saved: MASK_08_mouse_bite_10.png
# Saved: MASK_09_mouse_bite_01.png
# Saved: MASK_09_mouse_bite_02.png
# Saved: MASK_09_mouse_bite_03.png
# Saved: MASK_09_mouse_bite_04.png
# Saved: MASK_09_mouse_bite_05.png
# Saved: MASK_09_mouse_bite_06.png
# Saved: MASK_09_mouse_bite_07.png
# Saved: MASK_09_mouse_bite_08.png
# Saved: MASK_09_mouse_bite_09.png
# Saved: MASK_09_mouse_bite_10.png
# Saved: MASK_10_mouse_bite_01.png
# Saved: MASK_10_mouse_bite_02.png
# Saved: MASK_10_mouse_bite_03.png
# Saved: MASK_10_mouse_bite_04.png
# Saved: MASK_10_mouse_bite_05.png
# Saved: MASK_11_mouse_bite_01.png
# Saved: MASK_11_mouse_bite_02.png
# Saved: MASK_11_mouse_bite_03.png
# Saved: MASK_11_mouse_bite_04.png
# Saved: MASK_11_mouse_bite_05.png
# Saved: MASK_11_mouse_bite_06.png
# Saved: MASK_11_mouse_bite_07.png
# Saved: MASK_11_mouse_bite_08.png
# Saved: MASK_11_mouse_bite_09.png
# Saved: MASK_11_mouse_bite_10.png
# Saved: MASK_12_mouse_bite_01.png
# Saved: MASK_12_mouse_bite_02.png
# Saved: MASK_12_mouse_bite_03.png
# Saved: MASK_12_mouse_bite_04.png
# Saved: MASK_12_mouse_bite_05.png
# Saved: MASK_12_mouse_bite_06.png
# Saved: MASK_12_mouse_bite_07.png
# Saved: MASK_12_mouse_bite_08.png
# Saved: MASK_12_mouse_bite_09.png
# Saved: MASK_12_mouse_bite_10.png
#
# Processing defect type: Open_circuit
# Saved: MASK_01_open_circuit_01.png
# Saved: MASK_01_open_circuit_02.png
# Saved: MASK_01_open_circuit_03.png
# Saved: MASK_01_open_circuit_04.png
# Saved: MASK_01_open_circuit_05.png
# Saved: MASK_01_open_circuit_06.png
# Saved: MASK_01_open_circuit_07.png
# Saved: MASK_01_open_circuit_08.png
# Saved: MASK_01_open_circuit_09.png
# Saved: MASK_01_open_circuit_10.png
# Saved: MASK_01_open_circuit_11.png
# Saved: MASK_01_open_circuit_12.png
# Saved: MASK_01_open_circuit_13.png
# Saved: MASK_01_open_circuit_14.png
# Saved: MASK_01_open_circuit_15.png
# Saved: MASK_01_open_circuit_16.png
# Saved: MASK_01_open_circuit_17.png
# Saved: MASK_01_open_circuit_18.png
# Saved: MASK_01_open_circuit_19.png
# Saved: MASK_01_open_circuit_20.png
# Saved: MASK_04_open_circuit_01.png
# Saved: MASK_04_open_circuit_02.png
# Saved: MASK_04_open_circuit_03.png
# Saved: MASK_04_open_circuit_04.png
# Saved: MASK_04_open_circuit_05.png
# Saved: MASK_04_open_circuit_06.png
# Saved: MASK_04_open_circuit_07.png
# Saved: MASK_04_open_circuit_08.png
# Saved: MASK_04_open_circuit_09.png
# Saved: MASK_04_open_circuit_10.png
# Saved: MASK_04_open_circuit_11.png
# Saved: MASK_04_open_circuit_12.png
# Saved: MASK_04_open_circuit_13.png
# Saved: MASK_04_open_circuit_14.png
# Saved: MASK_04_open_circuit_15.png
# Saved: MASK_04_open_circuit_16.png
# Saved: MASK_04_open_circuit_17.png
# Saved: MASK_04_open_circuit_18.png
# Saved: MASK_04_open_circuit_19.png
# Saved: MASK_04_open_circuit_20.png
# Saved: MASK_05_open_circuit_01.png
# Saved: MASK_05_open_circuit_02.png
# Saved: MASK_05_open_circuit_03.png
# Saved: MASK_05_open_circuit_04.png
# Saved: MASK_05_open_circuit_05.png
# Saved: MASK_05_open_circuit_06.png
# Saved: MASK_05_open_circuit_07.png
# Saved: MASK_05_open_circuit_08.png
# Saved: MASK_05_open_circuit_09.png
# Saved: MASK_05_open_circuit_10.png
# Saved: MASK_06_open_circuit_01.png
# Saved: MASK_06_open_circuit_02.png
# Saved: MASK_06_open_circuit_03.png
# Saved: MASK_06_open_circuit_04.png
# Saved: MASK_06_open_circuit_05.png
# Saved: MASK_06_open_circuit_06.png
# Saved: MASK_06_open_circuit_07.png
# Saved: MASK_06_open_circuit_08.png
# Saved: MASK_06_open_circuit_09.png
# Saved: MASK_06_open_circuit_10.png
# Saved: MASK_07_open_circuit_01.png
# Saved: MASK_07_open_circuit_02.png
# Saved: MASK_07_open_circuit_03.png
# Saved: MASK_07_open_circuit_04.png
# Saved: MASK_07_open_circuit_05.png
# Saved: MASK_07_open_circuit_06.png
# Saved: MASK_07_open_circuit_07.png
# Saved: MASK_07_open_circuit_08.png
# Saved: MASK_07_open_circuit_09.png
# Saved: MASK_07_open_circuit_10.png
# Saved: MASK_08_open_circuit_01.png
# Saved: MASK_08_open_circuit_02.png
# Saved: MASK_08_open_circuit_03.png
# Saved: MASK_08_open_circuit_04.png
# Saved: MASK_08_open_circuit_05.png
# Saved: MASK_08_open_circuit_06.png
# Saved: MASK_08_open_circuit_07.png
# Saved: MASK_08_open_circuit_08.png
# Saved: MASK_08_open_circuit_09.png
# Saved: MASK_08_open_circuit_10.png
# Saved: MASK_09_open_circuit_01.png
# Saved: MASK_09_open_circuit_02.png
# Saved: MASK_09_open_circuit_03.png
# Saved: MASK_09_open_circuit_04.png
# Saved: MASK_09_open_circuit_05.png
# Saved: MASK_09_open_circuit_06.png
# Saved: MASK_09_open_circuit_07.png
# Saved: MASK_09_open_circuit_08.png
# Saved: MASK_09_open_circuit_09.png
# Saved: MASK_09_open_circuit_10.png
# Saved: MASK_10_open_circuit_01.png
# Saved: MASK_10_open_circuit_02.png
# Saved: MASK_10_open_circuit_03.png
# Saved: MASK_10_open_circuit_04.png
# Saved: MASK_10_open_circuit_05.png
# Saved: MASK_10_open_circuit_06.png
# Saved: MASK_11_open_circuit_01.png
# Saved: MASK_11_open_circuit_02.png
# Saved: MASK_11_open_circuit_03.png
# Saved: MASK_11_open_circuit_04.png
# Saved: MASK_11_open_circuit_05.png
# Saved: MASK_11_open_circuit_06.png
# Saved: MASK_11_open_circuit_07.png
# Saved: MASK_11_open_circuit_08.png
# Saved: MASK_11_open_circuit_09.png
# Saved: MASK_11_open_circuit_10.png
# Saved: MASK_12_open_circuit_01.png
# Saved: MASK_12_open_circuit_02.png
# Saved: MASK_12_open_circuit_03.png
# Saved: MASK_12_open_circuit_04.png
# Saved: MASK_12_open_circuit_05.png
# Saved: MASK_12_open_circuit_06.png
# Saved: MASK_12_open_circuit_07.png
# Saved: MASK_12_open_circuit_08.png
# Saved: MASK_12_open_circuit_09.png
# Saved: MASK_12_open_circuit_10.png
#
# Processing defect type: Short
# Saved: MASK_01_short_01.png
# Saved: MASK_01_short_02.png
# Saved: MASK_01_short_03.png
# Saved: MASK_01_short_04.png
# Saved: MASK_01_short_05.png
# Saved: MASK_01_short_06.png
# Saved: MASK_01_short_07.png
# Saved: MASK_01_short_08.png
# Saved: MASK_01_short_09.png
# Saved: MASK_01_short_10.png
# Saved: MASK_01_short_11.png
# Saved: MASK_01_short_12.png
# Saved: MASK_01_short_13.png
# Saved: MASK_01_short_14.png
# Saved: MASK_01_short_15.png
# Saved: MASK_01_short_16.png
# Saved: MASK_01_short_17.png
# Saved: MASK_01_short_18.png
# Saved: MASK_01_short_19.png
# Saved: MASK_01_short_20.png
# Saved: MASK_04_short_01.png
# Saved: MASK_04_short_02.png
# Saved: MASK_04_short_03.png
# Saved: MASK_04_short_04.png
# Saved: MASK_04_short_05.png
# Saved: MASK_04_short_06.png
# Saved: MASK_04_short_07.png
# Saved: MASK_04_short_08.png
# Saved: MASK_04_short_09.png
# Saved: MASK_04_short_10.png
# Saved: MASK_04_short_11.png
# Saved: MASK_04_short_12.png
# Saved: MASK_04_short_13.png
# Saved: MASK_04_short_14.png
# Saved: MASK_04_short_15.png
# Saved: MASK_04_short_16.png
# Saved: MASK_04_short_17.png
# Saved: MASK_04_short_18.png
# Saved: MASK_04_short_19.png
# Saved: MASK_04_short_20.png
# Saved: MASK_05_short_01.png
# Saved: MASK_05_short_02.png
# Saved: MASK_05_short_03.png
# Saved: MASK_05_short_04.png
# Saved: MASK_05_short_05.png
# Saved: MASK_05_short_06.png
# Saved: MASK_05_short_07.png
# Saved: MASK_05_short_08.png
# Saved: MASK_05_short_09.png
# Saved: MASK_05_short_10.png
# Saved: MASK_06_short_01.png
# Saved: MASK_06_short_02.png
# Saved: MASK_06_short_03.png
# Saved: MASK_06_short_04.png
# Saved: MASK_06_short_05.png
# Saved: MASK_06_short_06.png
# Saved: MASK_06_short_07.png
# Saved: MASK_06_short_08.png
# Saved: MASK_06_short_09.png
# Saved: MASK_06_short_10.png
# Saved: MASK_06_short_11.png
# Saved: MASK_07_short_01.png
# Saved: MASK_07_short_02.png
# Saved: MASK_07_short_03.png
# Saved: MASK_07_short_04.png
# Saved: MASK_07_short_05.png
# Saved: MASK_07_short_06.png
# Saved: MASK_07_short_07.png
# Saved: MASK_07_short_08.png
# Saved: MASK_07_short_09.png
# Saved: MASK_07_short_10.png
# Saved: MASK_08_short_01.png
# Saved: MASK_08_short_02.png
# Saved: MASK_08_short_03.png
# Saved: MASK_08_short_04.png
# Saved: MASK_08_short_05.png
# Saved: MASK_08_short_06.png
# Saved: MASK_08_short_07.png
# Saved: MASK_08_short_08.png
# Saved: MASK_08_short_09.png
# Saved: MASK_08_short_10.png
# Saved: MASK_09_short_01.png
# Saved: MASK_09_short_02.png
# Saved: MASK_09_short_03.png
# Saved: MASK_09_short_04.png
# Saved: MASK_09_short_05.png
# Saved: MASK_09_short_06.png
# Saved: MASK_09_short_07.png
# Saved: MASK_09_short_08.png
# Saved: MASK_09_short_09.png
# Saved: MASK_09_short_10.png
# Saved: MASK_10_short_01.png
# Saved: MASK_10_short_02.png
# Saved: MASK_10_short_03.png
# Saved: MASK_10_short_04.png
# Saved: MASK_10_short_05.png
# Saved: MASK_11_short_01.png
# Saved: MASK_11_short_02.png
# Saved: MASK_11_short_03.png
# Saved: MASK_11_short_04.png
# Saved: MASK_11_short_05.png
# Saved: MASK_11_short_06.png
# Saved: MASK_11_short_07.png
# Saved: MASK_11_short_08.png
# Saved: MASK_11_short_09.png
# Saved: MASK_11_short_10.png
# Saved: MASK_12_short_01.png
# Saved: MASK_12_short_02.png
# Saved: MASK_12_short_03.png
# Saved: MASK_12_short_04.png
# Saved: MASK_12_short_05.png
# Saved: MASK_12_short_06.png
# Saved: MASK_12_short_07.png
# Saved: MASK_12_short_08.png
# Saved: MASK_12_short_09.png
# Saved: MASK_12_short_10.png
#
# Processing defect type: Spur
# Saved: MASK_01_spur_01.png
# Saved: MASK_01_spur_02.png
# Saved: MASK_01_spur_03.png
# Saved: MASK_01_spur_04.png
# Saved: MASK_01_spur_05.png
# Saved: MASK_01_spur_06.png
# Saved: MASK_01_spur_07.png
# Saved: MASK_01_spur_08.png
# Saved: MASK_01_spur_09.png
# Saved: MASK_01_spur_10.png
# Saved: MASK_01_spur_11.png
# Saved: MASK_01_spur_12.png
# Saved: MASK_01_spur_13.png
# Saved: MASK_01_spur_14.png
# Saved: MASK_01_spur_15.png
# Saved: MASK_01_spur_16.png
# Saved: MASK_01_spur_17.png
# Saved: MASK_01_spur_18.png
# Saved: MASK_01_spur_19.png
# Saved: MASK_01_spur_20.png
# Saved: MASK_04_spur_01.png
# Saved: MASK_04_spur_02.png
# Saved: MASK_04_spur_03.png
# Saved: MASK_04_spur_04.png
# Saved: MASK_04_spur_05.png
# Saved: MASK_04_spur_06.png
# Saved: MASK_04_spur_07.png
# Saved: MASK_04_spur_08.png
# Saved: MASK_04_spur_09.png
# Saved: MASK_04_spur_10.png
# Saved: MASK_04_spur_11.png
# Saved: MASK_04_spur_12.png
# Saved: MASK_04_spur_13.png
# Saved: MASK_04_spur_14.png
# Saved: MASK_04_spur_15.png
# Saved: MASK_04_spur_16.png
# Saved: MASK_04_spur_17.png
# Saved: MASK_04_spur_18.png
# Saved: MASK_04_spur_19.png
# Saved: MASK_04_spur_20.png
# Saved: MASK_05_spur_01.png
# Saved: MASK_05_spur_02.png
# Saved: MASK_05_spur_03.png
# Saved: MASK_05_spur_04.png
# Saved: MASK_05_spur_05.png
# Saved: MASK_05_spur_06.png
# Saved: MASK_05_spur_07.png
# Saved: MASK_05_spur_08.png
# Saved: MASK_05_spur_09.png
# Saved: MASK_05_spur_10.png
# Saved: MASK_06_spur_01.png
# Saved: MASK_06_spur_02.png
# Saved: MASK_06_spur_03.png
# Saved: MASK_06_spur_04.png
# Saved: MASK_06_spur_05.png
# Saved: MASK_06_spur_06.png
# Saved: MASK_06_spur_07.png
# Saved: MASK_06_spur_08.png
# Saved: MASK_06_spur_09.png
# Saved: MASK_06_spur_10.png
# Saved: MASK_07_spur_01.png
# Saved: MASK_07_spur_02.png
# Saved: MASK_07_spur_03.png
# Saved: MASK_07_spur_04.png
# Saved: MASK_07_spur_05.png
# Saved: MASK_07_spur_06.png
# Saved: MASK_07_spur_07.png
# Saved: MASK_07_spur_08.png
# Saved: MASK_07_spur_09.png
# Saved: MASK_07_spur_10.png
# Saved: MASK_08_spur_01.png
# Saved: MASK_08_spur_02.png
# Saved: MASK_08_spur_03.png
# Saved: MASK_08_spur_04.png
# Saved: MASK_08_spur_05.png
# Saved: MASK_08_spur_06.png
# Saved: MASK_08_spur_07.png
# Saved: MASK_08_spur_08.png
# Saved: MASK_08_spur_09.png
# Saved: MASK_08_spur_10.png
# Saved: MASK_09_spur_01.png
# Saved: MASK_09_spur_02.png
# Saved: MASK_09_spur_03.png
# Saved: MASK_09_spur_04.png
# Saved: MASK_09_spur_05.png
# Saved: MASK_09_spur_06.png
# Saved: MASK_09_spur_07.png
# Saved: MASK_09_spur_08.png
# Saved: MASK_09_spur_09.png
# Saved: MASK_09_spur_10.png
# Saved: MASK_10_spur_01.png
# Saved: MASK_10_spur_02.png
# Saved: MASK_10_spur_03.png
# Saved: MASK_10_spur_04.png
# Saved: MASK_10_spur_05.png
# Saved: MASK_11_spur_01.png
# Saved: MASK_11_spur_02.png
# Saved: MASK_11_spur_03.png
# Saved: MASK_11_spur_04.png
# Saved: MASK_11_spur_05.png
# Saved: MASK_11_spur_06.png
# Saved: MASK_11_spur_07.png
# Saved: MASK_11_spur_08.png
# Saved: MASK_11_spur_09.png
# Saved: MASK_11_spur_10.png
# Saved: MASK_12_spur_01.png
# Saved: MASK_12_spur_02.png
# Saved: MASK_12_spur_03.png
# Saved: MASK_12_spur_04.png
# Saved: MASK_12_spur_05.png
# Saved: MASK_12_spur_06.png
# Saved: MASK_12_spur_07.png
# Saved: MASK_12_spur_08.png
# Saved: MASK_12_spur_09.png
# Saved: MASK_12_spur_10.png
#
# Processing defect type: Spurious_copper
# Saved: MASK_01_spurious_copper_01.png
# Saved: MASK_01_spurious_copper_02.png
# Saved: MASK_01_spurious_copper_03.png
# Saved: MASK_01_spurious_copper_04.png
# Saved: MASK_01_spurious_copper_05.png
# Saved: MASK_01_spurious_copper_06.png
# Saved: MASK_01_spurious_copper_07.png
# Saved: MASK_01_spurious_copper_08.png
# Saved: MASK_01_spurious_copper_09.png
# Saved: MASK_01_spurious_copper_10.png
# Saved: MASK_01_spurious_copper_11.png
# Saved: MASK_01_spurious_copper_12.png
# Saved: MASK_01_spurious_copper_13.png
# Saved: MASK_01_spurious_copper_14.png
# Saved: MASK_01_spurious_copper_15.png
# Saved: MASK_01_spurious_copper_16.png
# Saved: MASK_01_spurious_copper_17.png
# Saved: MASK_01_spurious_copper_18.png
# Saved: MASK_01_spurious_copper_19.png
# Saved: MASK_01_spurious_copper_20.png
# Saved: MASK_04_spurious_copper_01.png
# Saved: MASK_04_spurious_copper_02.png
# Saved: MASK_04_spurious_copper_03.png
# Saved: MASK_04_spurious_copper_04.png
# Saved: MASK_04_spurious_copper_05.png
# Saved: MASK_04_spurious_copper_06.png
# Saved: MASK_04_spurious_copper_07.png
# Saved: MASK_04_spurious_copper_08.png
# Saved: MASK_04_spurious_copper_09.png
# Saved: MASK_04_spurious_copper_10.png
# Saved: MASK_04_spurious_copper_11.png
# Saved: MASK_04_spurious_copper_12.png
# Saved: MASK_04_spurious_copper_13.png
# Saved: MASK_04_spurious_copper_14.png
# Saved: MASK_04_spurious_copper_15.png
# Saved: MASK_04_spurious_copper_16.png
# Saved: MASK_04_spurious_copper_17.png
# Saved: MASK_04_spurious_copper_18.png
# Saved: MASK_04_spurious_copper_19.png
# Saved: MASK_04_spurious_copper_20.png
# Saved: MASK_05_spurious_copper_01.png
# Saved: MASK_05_spurious_copper_02.png
# Saved: MASK_05_spurious_copper_03.png
# Saved: MASK_05_spurious_copper_04.png
# Saved: MASK_05_spurious_copper_05.png
# Saved: MASK_05_spurious_copper_06.png
# Saved: MASK_05_spurious_copper_07.png
# Saved: MASK_05_spurious_copper_08.png
# Saved: MASK_05_spurious_copper_09.png
# Saved: MASK_05_spurious_copper_10.png
# Saved: MASK_06_spurious_copper_01.png
# Saved: MASK_06_spurious_copper_02.png
# Saved: MASK_06_spurious_copper_03.png
# Saved: MASK_06_spurious_copper_04.png
# Saved: MASK_06_spurious_copper_05.png
# Saved: MASK_06_spurious_copper_06.png
# Saved: MASK_06_spurious_copper_07.png
# Saved: MASK_06_spurious_copper_08.png
# Saved: MASK_06_spurious_copper_09.png
# Saved: MASK_06_spurious_copper_10.png
# Saved: MASK_07_spurious_copper_01.png
# Saved: MASK_07_spurious_copper_02.png
# Saved: MASK_07_spurious_copper_03.png
# Saved: MASK_07_spurious_copper_04.png
# Saved: MASK_07_spurious_copper_05.png
# Saved: MASK_07_spurious_copper_06.png
# Saved: MASK_07_spurious_copper_07.png
# Saved: MASK_07_spurious_copper_08.png
# Saved: MASK_07_spurious_copper_09.png
# Saved: MASK_07_spurious_copper_10.png
# Saved: MASK_08_spurious_copper_01.png
# Saved: MASK_08_spurious_copper_02.png
# Saved: MASK_08_spurious_copper_03.png
# Saved: MASK_08_spurious_copper_04.png
# Saved: MASK_08_spurious_copper_05.png
# Saved: MASK_08_spurious_copper_06.png
# Saved: MASK_08_spurious_copper_07.png
# Saved: MASK_08_spurious_copper_08.png
# Saved: MASK_08_spurious_copper_09.png
# Saved: MASK_08_spurious_copper_10.png
# Saved: MASK_09_spurious_copper_01.png
# Saved: MASK_09_spurious_copper_02.png
# Saved: MASK_09_spurious_copper_03.png
# Saved: MASK_09_spurious_copper_04.png
# Saved: MASK_09_spurious_copper_05.png
# Saved: MASK_09_spurious_copper_06.png
# Saved: MASK_09_spurious_copper_07.png
# Saved: MASK_09_spurious_copper_08.png
# Saved: MASK_09_spurious_copper_09.png
# Saved: MASK_09_spurious_copper_10.png
# Saved: MASK_10_spurious_copper_01.png
# Saved: MASK_10_spurious_copper_02.png
# Saved: MASK_10_spurious_copper_03.png
# Saved: MASK_10_spurious_copper_04.png
# Saved: MASK_10_spurious_copper_05.png
# Saved: MASK_10_spurious_copper_06.png
# Saved: MASK_11_spurious_copper_01.png
# Saved: MASK_11_spurious_copper_02.png
# Saved: MASK_11_spurious_copper_03.png
# Saved: MASK_11_spurious_copper_04.png
# Saved: MASK_11_spurious_copper_05.png
# Saved: MASK_11_spurious_copper_06.png
# Saved: MASK_11_spurious_copper_07.png
# Saved: MASK_11_spurious_copper_08.png
# Saved: MASK_11_spurious_copper_09.png
# Saved: MASK_11_spurious_copper_10.png
# Saved: MASK_12_spurious_copper_01.png
# Saved: MASK_12_spurious_copper_02.png
# Saved: MASK_12_spurious_copper_03.png
# Saved: MASK_12_spurious_copper_04.png
# Saved: MASK_12_spurious_copper_05.png
# Saved: MASK_12_spurious_copper_06.png
# Saved: MASK_12_spurious_copper_07.png
# Saved: MASK_12_spurious_copper_08.png
# Saved: MASK_12_spurious_copper_09.png
# Saved: MASK_12_spurious_copper_10.png
#
# ✅ All defect masks have been generated successfully!
